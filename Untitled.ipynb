# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %%
tn = pd.read_csv("TransUnet-logs.csv")
un = pd.read_csv("Unet-logs.csv")

# %%
plt.plot(tn['mean_iou'], label='TransUnet')
plt.plot(un['mean_iou'], label='Unet')
plt.legend(['TransUnet', 'Unet'])
plt.title("Mean IoU: TransUnet vs Unet")
plt.show()

# %%
plt.plot(tn['val_mean_iou'], label='TransUnet')
plt.plot(un['val_mean_iou'], label='Unet')
plt.legend(['TransUnet', 'Unet'])
plt.title("Val Mean IoU: TransUnet vs Unet")
plt.show()

# %%
plt.plot(tn['loss'], label='TransUnet')
plt.plot(un['loss'], label='Unet')
plt.legend(['TransUnet', 'Unet'])
plt.title("Dice Loss: TransUnet vs Unet")
plt.show()

# %%
plt.plot(tn['val_loss'], label='TransUnet')
plt.plot(un['val_loss'], label='Unet')
plt.legend(['TransUnet', 'Unet'])
plt.title("Val Dice Loss: TransUnet vs Unet")
plt.show()

# %%
plt.plot(tn['loss'], label='train_loss')
plt.plot(tn['val_loss'], label='val_loss')
plt.legend(['train_loss', 'val_loss'])
plt.title("Train vs Val loss: TransUnet")
plt.show()

# %%
plt.plot(tn['mean_iou'], label='train_mean_iou')
plt.plot(tn['val_mean_iou'], label='val_mean_iou')
plt.legend(['train_mean_iou', 'val_mean_iou'])
plt.title("Train vs Val mean IoU: TransUnet")
plt.show()

# %%
plt.plot(un['loss'], label='train_loss')
plt.plot(un['val_loss'], label='val_loss')
plt.legend(['train_loss', 'val_loss'])
plt.title("Train vs Val loss: Unet")
plt.show()

# %%
plt.plot(un['mean_iou'], label='train_mean_iou')
plt.plot(un['val_mean_iou'], label='val_mean_iou')
plt.legend(['train_mean_iou', 'val_mean_iou'])
plt.title("Train vs Val mean IoU: Unet")
plt.show()

# %%
def predict(image, model1):
    img = cv2.imread(image)
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    img = np.array(img)/255
    img = img.reshape((1,256,256,3))
    prediction1 = model1.predict(img)
    prediction1 = tf.clip_by_value(prediction1, 0.0, 1.0)
#     prediction2 = model2.predict(img)
#     prediction2 = tf.clip_by_value(prediction2, 0.0, 1.0)
    pred1 = prediction1 * 255
    pred1 = np.array(prediction1).reshape((256,256,3))
#     pred2 = prediction2 * 255
#     pred2 = np.array(prediction2).reshape((256,256,3))
    img = img.reshape((256,256,3))
    return img, pred1

# %%
save_path = "weights"
saved_model_path = save_path + "/model"
model1 = tf.keras.models.load_model(
    saved_model_path, compile=False)
# Out:
# WARNING:tensorflow:Unable to restore custom metric. Please ensure that the layer implements `get_config` and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.

# %%
val_input_names = ["/Users/srinathramalingam/Desktop/codebase/Jupyter_predictions_Nearspace/MACH-77-it2/val/images/" + i for i in os.listdir("/Users/srinathramalingam/Desktop/codebase/Jupyter_predictions_Nearspace/MACH-77-it2/val/images")]

# %%
for file in range(len(val_input_names)):
    img, pred1 = predict(val_input_names[file], model1)
    
    plt.subplot(1, 3, 1)
    plt.imshow(img)

    plt.subplot(1, 3, 2)
    plt.imshow(pred1)

    plt.show()
# Out:
# ...
# 1/1 [==============================] - 0s 377ms/step
